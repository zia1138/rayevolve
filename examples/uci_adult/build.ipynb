# %%
from sklearn.datasets import fetch_openml
import pandas as pd

X, y = fetch_openml("adult", version=2, as_frame=True, return_X_y=True)
X.isna().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# dtype: int64

# %%
# Make target binary: 1 for '>50K', 0 for '<=50K'
y = y.astype(str)
y = (y == ">50K").astype(int)

# %%
# Create a single train/val split with a fixed seed and save indices
from sklearn.model_selection import train_test_split

SEED = 42
TEST_SIZE = 1.0/3

# Perform stratified split to preserve class balance
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=SEED, stratify=y
)

# %%
X_train.index
# Out:
# Index([43630, 40796, 33798, 17454, 41161, 14063, 34730,  9186,  4559,  9488,
#        ...
#        12204, 47400,   969, 26955, 43143,  3820, 20602, 22129, 43502, 39897],
#       dtype='int64', length=32561)

# %%
X_val
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 38758   25           Private  130397          10th              6
# 36393   20           Private  110597  Some-college             10
# 37685   37           Private  238959       HS-grad              9
# 2221    28         Local-gov  104329  Some-college             10
# 32902   53       Federal-gov  105788     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 1931    43       Federal-gov  136105       HS-grad              9
# 29561   23           Private  388811       HS-grad              9
# 44384   52  Self-emp-not-inc  183146          12th              8
# 8746    34           Private  154120       Masters             14
# 20013   32           Private  107843       HS-grad              9
#
#            marital-status         occupation relationship                race  \
# 38758       Never-married    Farming-fishing    Unmarried  Amer-Indian-Eskimo
# 36393       Never-married              Sales    Own-child               White
# 37685  Married-civ-spouse       Adm-clerical         Wife               White
# 2221   Married-civ-spouse    Protective-serv      Husband               White
# 32902            Divorced    Exec-managerial    Unmarried               Black
# ...                   ...                ...          ...                 ...
# 1931   Married-civ-spouse       Adm-clerical         Wife               Black
# 29561       Never-married       Adm-clerical    Own-child               White
# 44384  Married-civ-spouse    Exec-managerial      Husband               White
# 8746   Married-civ-spouse    Exec-managerial      Husband               White
# 20013  Married-civ-spouse  Machine-op-inspct      Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country
# 38758    Male             0             0              40  United-States
# 36393  Female             0             0              30  United-States
# 37685  Female             0             0              40  United-States
# 2221     Male             0             0              50  United-States
# 32902  Female             0             0              50  United-States
# ...       ...           ...           ...             ...            ...
# 1931   Female             0          1848              40  United-States
# 29561  Female             0             0              40  United-States
# 44384    Male             0             0              50  United-States
# 8746     Male         15024             0              60  United-States
# 20013    Male          5178             0              50  United-States
#
# [16281 rows x 14 columns]

# %%
X_train.to_csv('X_train.csv', index=True)
y_train.to_csv('y_train.csv', index=True)
X_val.to_csv('X_val.csv', index=True)
y_val.to_csv('y_val.csv', index=True)

print('Saved X_train.csv, y_train.csv, X_val.csv, y_val.csv')
# Out:
# Saved X_train.csv, y_train.csv, X_val.csv, y_val.csv

# %%
X_train = pd.read_csv('X_train.csv', index_col=0)
print(X_train.index)
print(y_train.index)
# Out:
# Index([43630, 40796, 33798, 17454, 41161, 14063, 34730,  9186,  4559,  9488,
#        ...
#        12204, 47400,   969, 26955, 43143,  3820, 20602, 22129, 43502, 39897],
#       dtype='int64', length=32561)
# Index([43630, 40796, 33798, 17454, 41161, 14063, 34730,  9186,  4559,  9488,
#        ...
#        12204, 47400,   969, 26955, 43143,  3820, 20602, 22129, 43502, 39897],
#       dtype='int64', length=32561)
